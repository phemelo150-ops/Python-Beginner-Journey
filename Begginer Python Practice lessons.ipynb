# %% [markdown]
# Code pratice beginner.Character Input,input strings types int.Exercise 1

# %%
name = input("What is your name : ")
print("Your name is " + name)
# Out:
# What is your name : Solly
# Your name is Solly

# %%
age = int(input("How old are you : "))
# Out:
# How old are you : 20

# %% [markdown]
# Odd Or Even,input if types int equality comparison numbers mod.Exercise 2

# %%
age = int(input("How old are you : "))
if age >= 18:
  print("You can watch PG18 movies")
elif age >= 13:
  print("You can watch PG movies")
else:
  print("You are not allowed to watch this movie")
# Out:
# How old are you : 5
# You are not allowed to watch this movie

# %% [markdown]
# List Less Than Ten,list numbers elements if conditional.Exercise 3

# %%
marks = int(input("Enter your marks: "))
if marks >= 90:
  print("A")
elif marks >= 80:
  print("B")
elif marks >= 70:
  print("C")
elif marks >= 60:
  print("D")
else:
  print("F")
# Out:
# Enter your marks: 100
# A

# %% [markdown]
# Divisors,number that divides evenly into another number.Exercise 4

# %%
x = range(2, 21, 2)
for elem in x:
  print(elem)

# %% [markdown]
# List Overlap.Exercise 5

# %%
list_of_student = ["Phmelo","Mmoloki","Thabo","Tshiamo","Bongani"]
name = input("Enter name of student: ")
if name in list_of_student:
  print("You are enrolled")
else:
  print("You are not enrolled")
# Out:
# Enter name of student: Thabo
# You are enrolled

# %%
list_of_fruits = ["Apple","banana","grapes","Orange"]
fruits = input("Enter name of fruit: ")
if fruits in list_of_fruits:
  print("fruit Available")
else:
  print("Fruit not Available")
# Out:
# Enter name of fruit: peach
# Fruit not Available

# %% [markdown]
# String Lists,strings lists index.Exercise 6

# %%
string = "Example"
for c in string:
  print("One letter : " + c)
# Out:
# One letter : E
# One letter : x
# One letter : a
# One letter : m
# One letter : p
# One letter : l
# One letter : e

# %%
string = "Phemelo"
s = string[0:9]
print(s)
# Out:
# Phemelo

# %% [markdown]
# List Comprehensions,make code more compact to accomplish tasks involving lists.Exercise 7

# %%
years_of_birth = [1990, 1991, 1990, 1990, 1992, 1991]
ages = [2026-year for year in years_of_birth]
print(ages)
# Out:
# [36, 35, 36, 36, 34, 35]

# %% [markdown]
# Rock Paper Scissors,While loops,Infinite loops,Break statements.Exercise 8

# %%
quit = input('Type "Exit" to quit: ')
while quit != 'Exit':
  quit = input('Type "Exit" to quit: ')
# Out:
# Type "Exit" to quit: quit
# Type "Exit" to quit: exit

# %%
i = 5
while i > 0:
  print("Inside the loop")

# %%
while true:
  user_command = input("Enter your commanr: ")
  if user_command == "quit":
    break
else:
  print("You typed" + user_command)
